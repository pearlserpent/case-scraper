# %%
from chart_patterns import detect_rectangles, detect_v_patterns
from candles import get_candles
import pandas as pd
from plot_patterns import plot_patterns

# %%
df = get_candles("ETHUSD", resolution="15m", days_back=1)

# %%
rectangles = detect_rectangles(df)

# %%
# assuming df, v_patterns, rectangles already computed
v_patterns = detect_v_patterns(df)
rectangles = detect_rectangles(df)

fig, ax = plot_patterns(df, rectangles)
